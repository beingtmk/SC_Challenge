# %% [markdown]
# <h2>Importing all required library and reading data from csv files</h2>

# %%
# %matplotlib inline
from scipy import stats
import pandas as pd
import numpy as np
monthly_data = pd.read_csv('Monthly_data_cmo.csv')
msp_data = pd.read_csv('CMO_MSP_Mandi.csv')

# %% [markdown]
# <h4>Lowercasing the data </h4>

# %%
monthly_data = monthly_data.apply(lambda x: x.astype(str).str.lower())

# %% [markdown]
# <h4>Removing whitespace from 'APMC' &amp; 'Commodity'</h4>

# %%
monthly_data.APMC = monthly_data.APMC.map(lambda x: x.lstrip(' '))
monthly_data.Commodity = monthly_data.Commodity.map(lambda x: x.lstrip(' '))

# %% [markdown]
# <h4>Sorting the data by commodity name</h4>

# %%
monthly_data.sort_values(["Commodity"], axis=0, ascending=[True], inplace=True)

# %% [markdown]
# <h2>Segmenting the data year-wise</h2>

# %%
monthly_data.Year = monthly_data.Year.astype(int)
monthly_data.modal_price = monthly_data.modal_price.astype(float)
year14 = monthly_data[monthly_data['Year'] == 2014]
year15 = monthly_data[monthly_data['Year'] == 2015]
year16 = monthly_data[monthly_data['Year'] == 2016]
year15.shape
# Out:
# (25557, 11)

# %% [markdown]
# <h4>Cross checking the authenticity of segmented data</h4>

# %%
year14.shape[0] + year15.shape[0] + year16.shape[0] == monthly_data.shape[0]
# Out:
# True

# %%
year14.columns
# Out:
# Index(['APMC', 'Commodity', 'Year', 'Month', 'arrivals_in_qtl', 'min_price',
#        'max_price', 'modal_price', 'date', 'district_name', 'state_name'],
#       dtype='object')

# %% [markdown]
# <h2>Representing the outliers using Boxplot</h2>

# %%
ax14 = year14.boxplot(by='Commodity', column=['modal_price'], grid=False)
ax14.set_xlabel("Commodity")
ax14.set_ylabel("Modal_Price")
ax14

# %%
ax15 = year15.boxplot(by='Commodity', column=['modal_price'], grid=False)
ax15.set_xlabel("Commodity")
ax15.set_ylabel("Modal_Price")
ax15

# %%
ax16 = year16.boxplot(by='Commodity', column=['modal_price'], grid=False)
ax16.set_xlabel("Commodity")
ax16.set_ylabel("Modal_Price")
ax16

# %% [markdown]
# <h2>Function to filter outliers </h2>

# %%
def outliers(x):
    Q1 = x.quantile(0.25)
    Q3 = x.quantile(0.75)
    IQR = Q3 - Q1
    return ((x < (Q1 - 1.5 * IQR)) | (x > (Q3 + 1.5 * IQR)))

# %%
year14_outliers = outliers(year14.modal_price)
year15_outliers = outliers(year15.modal_price)
year16_outliers = outliers(year16.modal_price)

# %% [markdown]
# <h4>Total number of outliers in the dataset </h4>

# %%
(year16_outliers).sum() + (year15_outliers).sum() + (year14_outliers).sum()
# Out:
# 2320

# %% [markdown]
# <h3>Saving outliers in a file </h3>

# %%
outliers_list = pd.concat((year14[year14_outliers], year15[year15_outliers], year16[year16_outliers]))
outliers_file = outliers_list.reset_index()
outliers_file.drop('index', axis=1, inplace=True)
outliers_file.index = np.arange(1, len(outliers_file) + 1)
#outliers_file.to_csv('outliers_file.csv')
